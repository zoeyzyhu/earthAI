# %% [markdown]
# ### Choose one day to plot.

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Function to read data from file
def read_data(file_path):
    latitudes = []
    longitudes = []
    rad0_values = []
    
    with open(file_path, 'r') as file:
        for line in file:
            lat, lon, rad0 = map(float, line.split())
            latitudes.append(lat)
            longitudes.append(lon)
            rad0_values.append(rad0)
    
    return latitudes, longitudes, rad0_values

# File path containing the data
file_path_01012015 = "/home/hzin/earthAI/logs/latlonrad_0101_2015.txt"  # Change this to your file path

# Read data from the file
latitudes1, longitudes1, rad0_values1 = read_data(file_path_01012015)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(longitudes, latitudes, c=rad0_values, cmap='viridis', marker='o', edgecolors='none')
plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Plot of latitudes, longitudes, and rad0 values (2015-01-01)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Choose a second day to plot.

# %%
# Function to read data from file
def read_data(file_path):
    latitudes = []
    longitudes = []
    rad0_values = []
    granules = []
    
    with open(file_path, 'r') as file:
        for line in file:
            lat, lon, rad0, gra = map(float, line.split())
            latitudes.append(lat)
            longitudes.append(lon)
            rad0_values.append(rad0)
            granules.append(gra)
    
    return latitudes, longitudes, rad0_values, granules

# File path containing the data
file_path_01022015 = "/home/hzin/earthAI/logs/latlonradgra_0102_2015.txt"  # Change this to your file path

# Read data from the file
latitudes2, longitudes2, rad0_values2, granules2 = read_data(file_path_01022015)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(longitudes, latitudes, c=rad0_values, cmap='viridis', marker='o', edgecolors='none')
plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Plot of latitudes, longitudes, and rad0 values (2015-01-02)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Read data with pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to read data from file
def read_data(file_path):
    # Define column names
    column_names = ['lat', 'lon', 'rad0', 'gra', 'd']  # Assuming the columns are lat, lon, rad0, and d
    
    # Read data from file with specified column names
    df = pd.read_csv(file_path, names=column_names, sep='\t')
    return df

# %% [markdown]
# ### Plot with Pandas and Matplotlib

# %%
# File path containing the data
file_path = "/home/hzin/earthAI/logs/latlonradgrad_01030104_2015.txt"  # Change this to your file path

# Read data from the file
data = read_data(file_path)

data.columns
data.describe()
data.head()
# Out:
#          lat        lon       rad0  gra           d
# 0  23.916865 -88.867205  47.009384  187  2015-01-03
# 1  23.995086 -88.492760  46.006832  187  2015-01-03
# 2  24.069918 -88.130175  44.755527  187  2015-01-03
# 3  24.137543 -87.799137  43.006325  187  2015-01-03
# 4  24.202780 -87.476275  44.506592  187  2015-01-03

# %%
# Choose the date you want to plot
desired_date3 = "2015-01-04"  # Change this to the date you want to plot

# Filter data for the desired date
data_for_day3 = data[data['d'] == desired_date3]

# Plot the data
plt.figure(figsize=(10, 6))
plt.scatter(data_for_day3['lon'], data_for_day3['lat'], c=data_for_day3['rad0'], cmap='viridis', marker='o', edgecolors='none')
plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Plot of latitudes, longitudes, and rad0 values for {desired_date}')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot overlaying: overall and small-range

# %%
# Choose the date you want to plot
desired_date4 = "2015-01-04"  # Change this to the date you want to plot
desired_date3 = "2015-01-03"  # Change this to the date you want to plot

# Filter data for the desired date
data_for_day3 = data[data['d'] == desired_date3]
data_for_day4 = data[data['d'] == desired_date4]

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.xlim(-130, -70)
plt.ylim(10, 50)
#plt.scatter(longitudes1, latitudes1, c=rad0_values1, cmap='viridis', marker='o', edgecolors='orange', alpha=0.01)
plt.scatter(longitudes2, latitudes2, c=rad0_values2, cmap='viridis', marker='o', edgecolors='red', alpha=0.01)
#plt.scatter(data_for_day3['lon'], data_for_day3['lat'], c=data_for_day3['rad0'], cmap='viridis', marker='o', edgecolors='blue', alpha=0.01)
plt.scatter(data_for_day4['lon'], data_for_day4['lat'], c=data_for_day4['rad0'], cmap='viridis', marker='o', edgecolors='green', alpha=0.01)

plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Plot of latitudes, longitudes, and rad0 values for 2015/01/02 & 04')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.xlim(-105, -104)
plt.ylim(31, 34)
plt.scatter(data_for_day3['lon'], data_for_day3['lat'], c=data_for_day3['rad0'], cmap='viridis', marker='o', edgecolors='blue', alpha=0.5)
plt.scatter(data_for_day4['lon'], data_for_day4['lat'], c=data_for_day4['rad0'], cmap='viridis', marker='o', edgecolors='green', alpha=0.5)
plt.scatter(longitudes1, latitudes1, c=rad0_values1, cmap='viridis', marker='o', edgecolors='yellow', alpha=0.5)
plt.scatter(longitudes2, latitudes2, c=rad0_values2, cmap='viridis', marker='o', edgecolors='red', alpha=0.5)

plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Plot of latitudes, longitudes, and rad0 values for 2015/01/01-04')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.xlim(-110, -80)
plt.ylim(25, 40)
plt.scatter(longitudes1, latitudes1, c=rad0_values1, cmap='viridis', marker='o', edgecolors='yellow', alpha=0.05)
plt.scatter(longitudes2, latitudes2, c=rad0_values2, cmap='viridis', marker='o', edgecolors='red', alpha=0.05)
plt.scatter(data_for_day3['lon'], data_for_day3['lat'], c=data_for_day3['rad0'], cmap='viridis', marker='o', edgecolors='blue', alpha=0.05)
plt.scatter(data_for_day4['lon'], data_for_day4['lat'], c=data_for_day4['rad0'], cmap='viridis', marker='o', edgecolors='green', alpha=0.05)


plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Plot of latitudes, longitudes, and rad0 values for 2015/01/01-04')
plt.grid(True)
plt.show()

# %% [markdown]
# With four different plots.

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot data on each subplot
axs[0, 0].scatter(longitudes1, latitudes1, c=rad0_values1, cmap='viridis', marker='o', edgecolors='yellow', alpha=0.05)
axs[0, 0].set_title('Day 1')

axs[0, 1].scatter(longitudes2, latitudes2, c=rad0_values2, cmap='viridis', marker='o', edgecolors='red', alpha=0.05)
axs[0, 1].set_title('Day 2')

axs[1, 0].scatter(data_for_day3['lon'], data_for_day3['lat'], c=data_for_day3['rad0'], cmap='viridis', marker='o', edgecolors='blue', alpha=0.05)
axs[1, 0].set_title('Day 3')

axs[1, 1].scatter(data_for_day4['lon'], data_for_day4['lat'], c=data_for_day4['rad0'], cmap='viridis', marker='o', edgecolors='green', alpha=0.05)
axs[1, 1].set_title('Day 4')

# Common settings
for ax in axs.flat:
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.set_xlim(-110, -90)
    ax.set_ylim(25, 40)
    ax.grid(True)

# Add colorbar
#fig.colorbar(axs[0, 0].scatter(longitudes1, latitudes1, c=rad0_values1, cmap='viridis', marker='o', edgecolors='yellow', alpha=0.05), ax=axs, label='rad0')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Plot two more days for comparison

# %%
# File path containing the data
file_path = "/home/hzin/earthAI/logs/latlonradgrad_01050106_2015.txt"  # Change this to your file path

# Read data from the file
data = read_data(file_path)

# %%
# Choose the date you want to plot
desired_date5 = "2015-01-05"  # Change this to the date you want to plot
desired_date6 = "2015-01-06"  # Change this to the date you want to plot

# Filter data for the desired date
data_for_day5 = data[data['d'] == desired_date5]
data_for_day6 = data[data['d'] == desired_date6]

# Plot the data
plt.figure(figsize=(10, 6))
plt.xlim(-130, -70)
plt.ylim(10, 50)
plt.scatter(data_for_day5['lon'], data_for_day5['lat'], c=data_for_day5['rad0'], cmap='viridis', marker='o', edgecolors='green', alpha=0.01)
plt.scatter(data_for_day6['lon'], data_for_day6['lat'], c=data_for_day6['rad0'], cmap='viridis', marker='o', edgecolors='blue', alpha=0.01)

plt.colorbar(label='rad0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Plot of latitudes, longitudes, and rad0 values for 2015/01/05-06')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Reset Workspace

# %%
reset %f
# Out:
# Don't know how to reset  %f, please run `%reset?` for details

# %% [markdown]
# ### Test Hive Query
#
# Need to set up connection of the Hive query to get the data. (not working yet)

# %%
from pyhive import hive
import pandas as pd
import matplotlib.pyplot as plt

# Establish connection to Hive server on localhost
#conn = hive.Connection(host="localhost", port=10000, username="hiveuser")
conn = hive.Connection(host='127.0.0.1', port=10000, auth='CUSTOM', database='airs', password='password');

# Example query
query = "USE airs; SELECT DISTINCT d, lat, lon FROM radiances WHERE d BETWEEN '2015-01-01' limit 100"

# Execute the query
cursor = conn.cursor()
cursor.execute(query)

# Fetch the data
data = cursor.fetchall()
# Out:
# Could not connect to any of [('127.0.0.1', 10000)]
# ---------------------------------------------------------------------------
# TTransportException                       Traceback (most recent call last)
# Cell In[160], line 7
#       3 import matplotlib.pyplot as plt
#       5 # Establish connection to Hive server on localhost
#       6 #conn = hive.Connection(host="localhost", port=10000, username="hiveuser")
# ----> 7 conn = hive.Connection(host='127.0.0.1', port=10000, auth='CUSTOM', database='airs', password='password');
#       9 # Example query
#      10 query = "USE airs; SELECT DISTINCT d, lat, lon FROM radiances WHERE d BETWEEN '2015-01-01' limit 100"
#
# File ~/env/lib64/python3.9/site-packages/pyhive/hive.py:269, in Connection.__init__(self, host, port, scheme, username, database, auth, configuration, kerberos_service_name, password, check_hostname, ssl_cert, thrift_transport)
#     266 protocol_version = ttypes.TProtocolVersion.HIVE_CLI_SERVICE_PROTOCOL_V6
# ...
